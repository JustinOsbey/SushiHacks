# %%
# !pip install ipywidgets
# !pip install diffusers
# !pip install transformers 
# !pip install accelerate
# !pip install -r requirements-fp8.txt
# %pip install flex-ai
# !pip install safetensors
# !pip install torch
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: ipywidgets in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: diffusers in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (0.31.0)
# Requirement already satisfied: importlib-metadata in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (0.26.1)
# Requirement already satisfied: numpy in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.23.2->diffusers) (4.11.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->diffusers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.2->diffusers) (0.4.6)
# Requirement already satisfied: transformers in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (4.46.0)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (0.26.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: accelerate in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: pyyaml in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (0.26.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface-hub>=0.21.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.21.0->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements-fp8.txt'
# Requirement already satisfied: flex-ai in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (0.39)
# Requirement already satisfied: datasets in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (3.0.2)
# Requirement already satisfied: matplotlib in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (3.9.2)
# Requirement already satisfied: pydantic in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (2.9.2)
# Requirement already satisfied: requests in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (2.32.3)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (0.4.6)
# Requirement already satisfied: transformers in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (4.46.0)
# Requirement already satisfied: pandas in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (2.2.3)
# Requirement already satisfied: torch in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (2.4.0)
# Requirement already satisfied: click in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (8.1.7)
# Requirement already satisfied: numpy==1.26.4 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (1.26.4)
# Requirement already satisfied: zstandard in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (0.23.0)
# Requirement already satisfied: tqdm in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from flex-ai) (4.66.5)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (18.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->flex-ai) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (0.26.1)
# Requirement already satisfied: packaging in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from datasets->flex-ai) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->flex-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->flex-ai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->flex-ai) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->flex-ai) (2024.8.30)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from matplotlib->flex-ai) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from pandas->flex-ai) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from pandas->flex-ai) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from pydantic->flex-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from pydantic->flex-ai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from pydantic->flex-ai) (4.11.0)
# Requirement already satisfied: sympy in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch->flex-ai) (1.12)
# Requirement already satisfied: networkx in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch->flex-ai) (3.3)
# Requirement already satisfied: jinja2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch->flex-ai) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers->flex-ai) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers->flex-ai) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from transformers->flex-ai) (0.20.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from aiohttp->datasets->flex-ai) (4.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from python-dateutil>=2.7->matplotlib->flex-ai) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from jinja2->torch->flex-ai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from sympy->torch->flex-ai) (1.3.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets->flex-ai) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: safetensors in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (0.4.5)
# Requirement already satisfied: torch in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (2.4.0)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: huggingface_hub in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (0.26.1)
# Requirement already satisfied: filelock in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: colorama in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface_hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osbey\appdata\local\anaconda3\envs\pytorch-gpu\lib\site-packages (from requests->huggingface_hub) (2024.8.30)

# %%
import torch
from diffusers import StableDiffusionPipeline
import transformers
from PIL import Image
import os

from huggingface_hub import hf_hub_download 
from huggingface_hub import login
from safetensors.torch import load_file

login("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")

model_path = hf_hub_download(repo_id="guozinan/PuLID", filename="pulid_v1.1.safetensors")

# Load weights using safetensors
model_weights = load_file(model_path)
# Out:
# pulid_v1.1.safetensors:   0%|          | 0.00/984M [00:00<?, ?B/s]
# c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\osbey\.cache\huggingface\hub\models--guozinan--PuLID. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
model_id = "guozinan/PuLID"  #from Hugging Face
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
#GPU Optimization code: idk if this will work on ur guys stuff
pipeline = StableDiffusionPipeline.from_pretrained(model_id)
pipeline = pipeline.to(device).half()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/guozinan/PuLID/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# Cell In[13], line 2
#       1 #GPU Optimization code: idk if this will work on ur guys stuff
# ----> 2 pipeline = StableDiffusionPipeline.from_pretrained(model_id)
#       3 pipeline = pipeline.to(device).half()
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\diffusers\pipelines\pipeline_utils.py:725, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     720     if pretrained_model_name_or_path.count("/") > 1:
#     721         raise ValueError(
#     722             f'The provided pretrained_model_name_or_path "{pretrained_model_name_or_path}"'
#     723             " is neither a valid local path nor a valid repo id. Please check the parameter."
#     724         )
# --> 725     cached_folder = cls.download(
#     726         pretrained_model_name_or_path,
#     727         cache_dir=cache_dir,
#     728         force_download=force_download,
#     729         proxies=proxies,
#     730         local_files_only=local_files_only,
#     731         token=token,
#     732         revision=revision,
#     733         from_flax=from_flax,
#     734         use_safetensors=use_safetensors,
#     735         use_onnx=use_onnx,
#     736         custom_pipeline=custom_pipeline,
#     737         custom_revision=custom_revision,
#     738         variant=variant,
#     739         load_connected_pipeline=load_connected_pipeline,
#     740         **kwargs,
#     741     )
#     742 else:
#     743     cached_folder = pretrained_model_name_or_path
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\diffusers\pipelines\pipeline_utils.py:1305, in DiffusionPipeline.download(cls, pretrained_model_name, **kwargs)
#    1301     logger.warning(warn_msg)
#    1303 model_filenames, variant_filenames = variant_compatible_siblings(filenames, variant=variant)
# -> 1305 config_file = hf_hub_download(
#    1306     pretrained_model_name,
#    1307     cls.config_name,
#    1308     cache_dir=cache_dir,
#    1309     revision=revision,
#    1310     proxies=proxies,
#    1311     force_download=force_download,
#    1312     token=token,
#    1313 )
#    1315 config_dict = cls._dict_from_json_file(config_file)
#    1316 ignore_filenames = config_dict.pop("_ignore_files", [])
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:862, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     842     return _hf_hub_download_to_local_dir(
#     843         # Destination
#     844         local_dir=local_dir,
#    (...)
#     859         local_files_only=local_files_only,
#     860     )
#     861 else:
# --> 862     return _hf_hub_download_to_cache_dir(
#     863         # Destination
#     864         cache_dir=cache_dir,
#     865         # File info
#     866         repo_id=repo_id,
#     867         filename=filename,
#     868         repo_type=repo_type,
#     869         revision=revision,
#     870         # HTTP info
#     871         endpoint=endpoint,
#     872         etag_timeout=etag_timeout,
#     873         headers=headers,
#     874         proxies=proxies,
#     875         token=token,
#     876         # Additional options
#     877         local_files_only=local_files_only,
#     878         force_download=force_download,
#     879     )
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:925, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     921         return pointer_path
#     923 # Try to get metadata (etag, commit_hash, url, size) from the server.
#     924 # If we can't, a HEAD request error is returned.
# --> 925 (url_to_download, etag, commit_hash, expected_size, head_call_error) = _get_metadata_or_catch_error(
#     926     repo_id=repo_id,
#     927     filename=filename,
#     928     repo_type=repo_type,
#     929     revision=revision,
#     930     endpoint=endpoint,
#     931     proxies=proxies,
#     932     etag_timeout=etag_timeout,
#     933     headers=headers,
#     934     token=token,
#     935     local_files_only=local_files_only,
#     936     storage_folder=storage_folder,
#     937     relative_filename=relative_filename,
#     938 )
#     940 # etag can be None for several reasons:
#     941 # 1. we passed local_files_only.
#     942 # 2. we don't have a connection
#    (...)
#     948 # If the specified revision is a commit hash, look inside "snapshots".
#     949 # If the specified revision is a branch or tag, look inside "refs".
#     950 if head_call_error is not None:
#     951     # Couldn't make a HEAD call => let's try to find a local file
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:1376, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1374 try:
#    1375     try:
# -> 1376         metadata = get_hf_file_metadata(
#    1377             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1378         )
#    1379     except EntryNotFoundError as http_error:
#    1380         if storage_folder is not None and relative_filename is not None:
#    1381             # Cache the non-existence of the file
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:1296, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1293 headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1295 # Retrieve metadata
# -> 1296 r = _request_wrapper(
#    1297     method="HEAD",
#    1298     url=url,
#    1299     headers=headers,
#    1300     allow_redirects=False,
#    1301     follow_relative_redirects=True,
#    1302     proxies=proxies,
#    1303     timeout=timeout,
#    1304 )
#    1305 hf_raise_for_status(r)
#    1307 # Return
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:277, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     275 # Recursively follow relative redirects
#     276 if follow_relative_redirects:
# --> 277     response = _request_wrapper(
#     278         method=method,
#     279         url=url,
#     280         follow_relative_redirects=False,
#     281         **params,
#     282     )
#     284     # If redirection, we redirect only relative paths.
#     285     # This is useful in case of a renamed repository.
#     286     if 300 <= response.status_code <= 399:
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\file_download.py:301, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     299 # Perform request and return if status_code is not in the retry list.
#     300 response = get_session().request(method=method, url=url, **params)
# --> 301 hf_raise_for_status(response)
#     302 return response
#
# File c:\Users\osbey\AppData\Local\anaconda3\envs\pytorch-gpu\lib\site-packages\huggingface_hub\utils\_http.py:417, in hf_raise_for_status(response, endpoint_name)
#     415 elif error_code == "EntryNotFound":
#     416     message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 417     raise _format(EntryNotFoundError, message, response) from e
#     419 elif error_code == "GatedRepo":
#     420     message = (
#     421         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     422     )
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-672482e4-179039d67ed0267724929255;1046aadb-9ad0-4331-bdad-af69e81e32a7)
#
# Entry Not Found for url: https://huggingface.co/guozinan/PuLID/resolve/main/model_index.json.

# %%
def get_user_input():
    # placeholder test 
    product_name = input("Enter the product name: ")
    product_description = input("Enter the product description: ")
    target_audience = input("Enter the preferred target audience: ")
    additional_instructions = input("Any additional instructions for marketing: ")

targeted_prompt = (
    "Create an eye-catching advertisement for {product_name}, aimed at {target_audience}. "
    "Highlight key qualities like {unique_features} and include text such as '{slogan}' in a visually appealing font."
)

return targeted_prompt

# reference_image_path = "?"  
reference_image_path = "none"
reference_image = None
if reference_image_path:
    reference_image = Image.open(reference_image_path)

# %%
print("Generating advertisement image...")
generated_images = pipeline(prompt=targeted_prompt, image=reference_image).images

output_path = "optimized_generated_ad.png"
generated_images[0].save(output_path)
print(f"Image successfully generated and saved as {output_path}")
